# %% [markdown]
# <span style="font-size: 14pt">MIPT, Advanced ML, Autumn 2017</span>
#
# <span style="font-size: 16pt"> HW#1 </span>
#
# <span style="color:blue; font-size: 12pt">Alexey Romanenko </span>,
# <span style="color:blue; font-size: 12pt; font-family: 'Verdana'">alexromsput@gmail.com</span>

# %% [markdown]
# <h1 align="center">Organization Info</h1>

# %% [markdown]
# **Дополнительный материал для выполнения дз**:
# - Лукишн Ю.П. Адаптивные методы краткосрочного прогнозирования временных рядов. Финансы и статистика. 2003, главы 1,4,5,7.
# - Магнус Я.Р., Катышев П.К., Пересецкий А.А. Эконометрика. Начальный курс., глава 11
#
# **Оформление дз**:
# - Присылайте выполненное задание на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2017_Aut_fall <номер_группы> <фамилия>``, к примеру -- ``ML2017_Aut_fall 401 ivanov``
# - Выполненное дз сохраните в файл ``<фамилия>_<группа>_task<номер>.ipnb``, к примеру -- ``ivanov_401_task1.ipnb``
#
# **Вопросы**:
# - Присылайте вопросы на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2017_Aut_fall Question <Содержание вопроса>``
#
# --------
# - **PS1**: Мы используем автоматические фильтры, и просто не найдем ваше дз, если вы не аккуратно его подпишите.
# - **PS2**: Напоминаем, что дедлайны жесткие, письма пришедшие после автоматически удаляются =( чтобы соблазна не было

# %% [markdown]
# <h1 align="center">Check Questions (15%)</h1>

# %% [markdown]
# Ответе на вопросы своими словами (загугленный материал надо пересказать), ответ обоснуйте (напишите и ОБЪЯСНИТЕ формулки если потребуется), если не выходит, то вернитесь к лекции дополнительным материалам:
#
# **Вопрос 1**: Опишите, как изменяется адаптивная способность алгоритма ЭСС при изменении параметра $\alpha$ от 0 до 1.
#
# **Ответ 1**: С его ростом предсказание меняется от константы $l_o$ до сдвинутого исходного ряда, т.к. при $\alpha \uparrow 1$ мы учитываем только последние точки, а при $\alpha \downarrow 0$ не смотрим ни на одну из них, т.е. сглаживаем ряд до константы.
#
# **Вопрос 2**: Каким следует выбрать параметр сглаживания тренда $\alpha_2$ в модели Хольта (линейный тренд) в случае, когда вы предсказываете временной ряд 1) с плавно меняющимя трендом; 2) стохастически меняющися трендом?
#
# **Ответ 2**: 1) Поменьше 2) Побольше - мы не хотим подстраиваться под шум, а плавный тренд хотим словить поскорее.
#
# **Вопрос 3**: Докажите  эквивалетность формул расчёта (в рекуррентной форме и в форме корректировки прогноза (correction error form) )скрытых компонент временного ряда в модели Тейла-Вейджа (период сезонность обозначается $p$):
# $$l_t = \alpha (y_t - s_{t-p}) + (1-\alpha) (l_{t-1} + b_{t-1} ) \color{red}{=} l_{t-1} + b_{t-1} + \alpha e_t;$$,
#     $$ b_t = \beta (l_{t} - l_{t-1} ) + (1-\beta) b_{t-1} \color{red}{=} b_{t-1} + \alpha\beta e_t;$$,
#     $$ s_t = \gamma (y_t-l_t) + (1-\gamma) s_{t-p} \color{red}{=} s_{t-p} + \gamma(1-\alpha)e_t.$$,
#
# **Ответ 3**:
#
# **Вопрос 4**: Выведите формулу расчёта скрытых компонент в форме корректировки прогноза (correction error form) временного ряда в модели ЭС с линейным затухающим трендом (WS with additive damped trend):
#
# $$\hat{y}_{t+d|t} = l_t + \left(\phi + \phi^2 + \dots + \phi^{d}\right) b_t.$$,
#
# Скрытые компоненты ВР согласно модели в рекуррентной форме записываются:
#     $$ l_{t}       = \alpha y_t + \left(1-\alpha\right) \left(l_{t-1} +\phi b_{t-1}\right),$$,
#     $$ b_t         = \beta \left(l_t - l_{t-1}\right) + \left(1-\beta\right)\phi b_{t-1}.$$
#
#
# **Ответ 4**:
#
# -----------
# PS: Если проверяющий не понял ответ на большинство вопросов, то будет пичалька. Пишите так, чтобы можно было разобраться.

# %% [markdown]
# **Вопрос 3**: Докажите  эквивалетность формул расчёта (в рекуррентной форме и в форме корректировки прогноза (correction error form) )скрытых компонент временного ряда в модели Тейла-Вейджа (период сезонность обозначается $p$):
# $$l_t = \alpha (y_t - s_{t-p}) + (1-\alpha) (l_{t-1} + b_{t-1} ) \color{red}{=} l_{t-1} + b_{t-1} + \alpha e_t;$$,
#     $$ b_t = \beta (l_{t} - l_{t-1} ) + (1-\beta) b_{t-1} \color{red}{=} b_{t-1} + \alpha\beta e_t;$$,
#     $$ s_t = \gamma (y_t-l_t) + (1-\gamma) s_{t-p} \color{red}{=} s_{t-p} + \gamma(1-\alpha)e_t.$$,
#
# **Ответ 3**:

# %% [markdown]
# $l_t=l_{t-1}+b_{t-1}+\alpha(y_t-s_{t-p})-\alpha(l_{t-1}+b_{t-1})=l_{t-1}+b_{t-1}+\alpha[y_t-(l_{t-1}+b_{t-1}+s_{t-p})]=l_{t-1} + b_{t-1} + \alpha e_t$

# %% [markdown]
# $b_t=\beta (l_{t} - l_{t-1} ) + (1-\beta) b_{t-1}=b_{t-1}+\beta[l_t-(l_{t-1}+b_{t-1})]= b_{t-1} + \alpha\beta e_t$

# %% [markdown]
# $s_t = s_{t-p} + \gamma (y_t-l_t-s_{t-p}) \color{red}{=} s_{t-p} + \gamma(1-\alpha)e_t$

# %% [markdown]
# <h1 align="center"> Practice</h1>
# #  1. reading data (5%)
#
#   * Download data for following data sets
#      - 1) <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv </span>(1 TS of monthly wage in Russia)

# %%
# start with this code
import pandas as pd
import numpy as np
from utils import InitExponentialSmoothing, BuildForecast, plotTSForecast
from utils import qualityRMSE, qualityMedianAE, qualityMACAPE, qualitySSE, qualityMSE, qualityMAPE 

# %matplotlib inline


wage = pd.read_csv('monthly-wage.csv', sep=';', decimal='.', index_col='Month', parse_dates=True, dayfirst=True)
# Put your code below
wage.plot(figsize=(15,5))

# %% [markdown]
# # 2. Build the Forecast with  IES (5%)
#
# You need to apply IES model (see seminar 1) for the TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
#
# * 0) Forecast Wage TS with SES $\alpha=.1$.
# * 1) Find the best param $\alpha$ of SES for data period from 09.1998 to 01.2015. Is the optimal value close to 0 or 1? (You
# can choose any loss function above).
# * 2) Draw the forecast that correspond to IES with optimial value $\alpha$ (use time steps from 09.1998 to 01.2017.)
#      Conclude whether IES can be used for this TS? If can not than explain why.
# * 3) Calculate loss of the forecast of TS in [02.2015, 01.2017]. (You can choose any Loss function from seminar 1).

# %% [markdown]
# ## 0)

# %%
ALPHA = np.array([0.1])
ESParamsArray = [{'alpha':alpha, 'AdaptationPeriod':10} for alpha in ALPHA]
FRC_WAGE = BuildForecast(h=1, ts=wage, step='M', AlgName='InitExponentialSmoothing', AlgTitle='IES',ParamsArray = ESParamsArray)
QualityStr = pd.DataFrame(index=wage.columns, columns=FRC_WAGE.keys())

ix = wage.loc['1998-09-01':'2015-01-01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = FRC_WAGE[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[ix], frc_wage.loc[ix])

QualityStr[QualityStr.columns].mean().sort_values()
algName = QualityStr[QualityStr.columns].mean().sort_values().index[0]
plotTSForecast(wage.loc['1998-09-01':'2017-01-01'], FRC_WAGE[algName].loc['1998-09-01':'2017-01-01'],
               alg_title='SES')

# %% [markdown]
# ## 1) Search for the optimal $\alpha$

# %%
ALPHA = np.linspace(0.01,1,100)
ESParamsArray = [{'alpha':alpha, 'AdaptationPeriod':10} for alpha in ALPHA]
FRC_WAGE = BuildForecast(h=1, ts=wage, step='M', AlgName='InitExponentialSmoothing', AlgTitle='IES',ParamsArray = ESParamsArray)

# %%
# compare ES parameters
QualityStr = pd.DataFrame(index=wage.columns, columns=FRC_WAGE.keys())

ix = wage.loc['1998-09-01':'2015-01-01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = FRC_WAGE[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[ix], frc_wage.loc[ix])

QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# IES {'alpha': 0.41000000000000003, 'AdaptationPeriod': 10}     0.058955
# IES {'alpha': 0.42000000000000004, 'AdaptationPeriod': 10}     0.058957
# IES {'alpha': 0.40000000000000002, 'AdaptationPeriod': 10}     0.058959
# IES {'alpha': 0.42999999999999999, 'AdaptationPeriod': 10}     0.058967
# IES {'alpha': 0.39000000000000001, 'AdaptationPeriod': 10}     0.058974
# IES {'alpha': 0.38, 'AdaptationPeriod': 10}                    0.058998
# IES {'alpha': 0.44, 'AdaptationPeriod': 10}                    0.058998
# IES {'alpha': 0.37, 'AdaptationPeriod': 10}                    0.059048
# IES {'alpha': 0.45000000000000001, 'AdaptationPeriod': 10}     0.059093
# IES {'alpha': 0.36000000000000004, 'AdaptationPeriod': 10}     0.059127
# IES {'alpha': 0.46000000000000002, 'AdaptationPeriod': 10}     0.059193
# IES {'alpha': 0.35000000000000003, 'AdaptationPeriod': 10}     0.059271
# IES {'alpha': 0.47000000000000003, 'AdaptationPeriod': 10}     0.059305
# IES {'alpha': 0.48000000000000004, 'AdaptationPeriod': 10}     0.059418
# IES {'alpha': 0.34000000000000002, 'AdaptationPeriod': 10}     0.059439
# IES {'alpha': 0.48999999999999999, 'AdaptationPeriod': 10}     0.059530
# IES {'alpha': 0.5, 'AdaptationPeriod': 10}                     0.059644
# IES {'alpha': 0.33000000000000002, 'AdaptationPeriod': 10}     0.059660
# IES {'alpha': 0.51000000000000001, 'AdaptationPeriod': 10}     0.059755
# IES {'alpha': 0.52000000000000002, 'AdaptationPeriod': 10}     0.059865
# IES {'alpha': 0.32000000000000001, 'AdaptationPeriod': 10}     0.059902
# IES {'alpha': 0.53000000000000003, 'AdaptationPeriod': 10}     0.059982
# IES {'alpha': 0.54000000000000004, 'AdaptationPeriod': 10}     0.060096
# IES {'alpha': 0.31, 'AdaptationPeriod': 10}                    0.060171
# IES {'alpha': 0.55000000000000004, 'AdaptationPeriod': 10}     0.060207
# IES {'alpha': 0.56000000000000005, 'AdaptationPeriod': 10}     0.060315
# IES {'alpha': 0.57000000000000006, 'AdaptationPeriod': 10}     0.060427
# IES {'alpha': 0.29999999999999999, 'AdaptationPeriod': 10}     0.060475
# IES {'alpha': 0.58000000000000007, 'AdaptationPeriod': 10}     0.060550
# IES {'alpha': 0.58999999999999997, 'AdaptationPeriod': 10}     0.060670
#                                                                  ...
# IES {'alpha': 0.95000000000000007, 'AdaptationPeriod': 10}     0.062993
# IES {'alpha': 0.96000000000000008, 'AdaptationPeriod': 10}     0.063035
# IES {'alpha': 0.96999999999999997, 'AdaptationPeriod': 10}     0.063081
# IES {'alpha': 0.97999999999999998, 'AdaptationPeriod': 10}     0.063142
# IES {'alpha': 0.24000000000000002, 'AdaptationPeriod': 10}     0.063168
# IES {'alpha': 0.98999999999999999, 'AdaptationPeriod': 10}     0.063245
# IES {'alpha': 1.0, 'AdaptationPeriod': 10}                     0.063358
# IES {'alpha': 0.23000000000000001, 'AdaptationPeriod': 10}     0.063797
# IES {'alpha': 0.22, 'AdaptationPeriod': 10}                    0.064487
# IES {'alpha': 0.21000000000000002, 'AdaptationPeriod': 10}     0.065303
# IES {'alpha': 0.20000000000000001, 'AdaptationPeriod': 10}     0.066311
# IES {'alpha': 0.19, 'AdaptationPeriod': 10}                    0.067519
# IES {'alpha': 0.18000000000000002, 'AdaptationPeriod': 10}     0.068931
# IES {'alpha': 0.17000000000000001, 'AdaptationPeriod': 10}     0.070519
# IES {'alpha': 0.16, 'AdaptationPeriod': 10}                    0.072301
# IES {'alpha': 0.15000000000000002, 'AdaptationPeriod': 10}     0.074440
# IES {'alpha': 0.14000000000000001, 'AdaptationPeriod': 10}     0.076927
# IES {'alpha': 0.13, 'AdaptationPeriod': 10}                    0.079735
# IES {'alpha': 0.12, 'AdaptationPeriod': 10}                    0.083020
# IES {'alpha': 0.11, 'AdaptationPeriod': 10}                    0.087037
# IES {'alpha': 0.099999999999999992, 'AdaptationPeriod': 10}    0.091835
# IES {'alpha': 0.089999999999999997, 'AdaptationPeriod': 10}    0.097632
# IES {'alpha': 0.080000000000000002, 'AdaptationPeriod': 10}    0.104629
# IES {'alpha': 0.069999999999999993, 'AdaptationPeriod': 10}    0.113653
# IES {'alpha': 0.060000000000000005, 'AdaptationPeriod': 10}    0.125705
# IES {'alpha': 0.050000000000000003, 'AdaptationPeriod': 10}    0.142220
# IES {'alpha': 0.040000000000000001, 'AdaptationPeriod': 10}    0.165993
# IES {'alpha': 0.029999999999999999, 'AdaptationPeriod': 10}    0.201528
# IES {'alpha': 0.02, 'AdaptationPeriod': 10}                    0.255876
# IES {'alpha': 0.01, 'AdaptationPeriod': 10}                    0.344577
# dtype: float64

# %% [markdown]
# ## 2) draw the forecast with optimial value $\alpha $

# %%
algName = QualityStr[QualityStr.columns].mean().sort_values().index[0]
plotTSForecast(wage.loc['1998-09-01':'2017-01-01'], FRC_WAGE[algName].loc['1998-09-01':'2017-01-01'],
               alg_title='SES')

# %% [markdown]
# ** Question**
#     * Does SES follow to the TS components?
# ** Answer**
#     * It doesn't, because model can't keep up with the pace of TS growth + TS has a clear upward linear trend and sort of seasonality.

# %% [markdown]
# ## 3) Calculate loss of the forecast of TS in [02.2015, 01.2017]

# %%
qualityMACAPE(wage.loc['2015-02-01':'2017-01-01'], FRC_WAGE[algName].loc['2015-02-01':'2017-01-01'])[0]
# Out:
# Real wage    0.0629
# dtype: float64

# %% [markdown]
# # 3. Winters model for Additive Seasonality (25%)
# You need to realize ES model for TS with additive seasonality and then use it for forecasting real TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
# * 1) Realize Winters model for Seasonal TS
# * 2) Find optimal params $\alpha$ (smoothing of level) and $\gamma$ (smoothing of seasonality) (use data from 09.1998 to 01.2015).(Loss function should be the same as in task 2.)
# * 3) Draw the forecast that correspond optimal values $\alpha$ and $\gamma$ (data from 09.1998 to 01.2017).
# * 4) Calculate accuracy of the forecast of TS in [02.2015, 01.2017] (Loss function should be the same as in task 2.). Compare it with accuracy of IES: is it better?
# * 5) Conclude whether Winter's ES can be used for this TS?

# %% [markdown]
# ## 1) -> utils.py
# ## 2)

# %%
# Put your code here
ALPHA = np.linspace(0.01,1,100) # season ~ year
WESParamsArray = [{'alpha':alpha, 'gamma':gamma, 'seasonality_period':12} for (alpha, gamma) in zip(ALPHA, ALPHA)]
FRC_WAGE_W = BuildForecast(h=1, ts=wage, step='M', AlgName='WintersExponentialSmoothing', AlgTitle='WES',ParamsArray = WESParamsArray)

# %%
# compare ES parameters
QualityStr = pd.DataFrame(index=wage.columns, columns=FRC_WAGE_W.keys())

ix = wage.loc['1998-09-01':'2015-01-01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = FRC_WAGE_W[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[ix], frc_wage.loc[ix])

QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# WES {'alpha': 0.58000000000000007, 'gamma': 0.58000000000000007, 'seasonality_period': 12}      0.023744
# WES {'alpha': 0.58999999999999997, 'gamma': 0.58999999999999997, 'seasonality_period': 12}      0.023747
# WES {'alpha': 0.59999999999999998, 'gamma': 0.59999999999999998, 'seasonality_period': 12}      0.023758
# WES {'alpha': 0.57000000000000006, 'gamma': 0.57000000000000006, 'seasonality_period': 12}      0.023764
# WES {'alpha': 0.60999999999999999, 'gamma': 0.60999999999999999, 'seasonality_period': 12}      0.023795
# WES {'alpha': 0.56000000000000005, 'gamma': 0.56000000000000005, 'seasonality_period': 12}      0.023806
# WES {'alpha': 0.62, 'gamma': 0.62, 'seasonality_period': 12}                                    0.023854
# WES {'alpha': 0.55000000000000004, 'gamma': 0.55000000000000004, 'seasonality_period': 12}      0.023884
# WES {'alpha': 0.63, 'gamma': 0.63, 'seasonality_period': 12}                                    0.023937
# WES {'alpha': 0.54000000000000004, 'gamma': 0.54000000000000004, 'seasonality_period': 12}      0.023979
# WES {'alpha': 0.64000000000000001, 'gamma': 0.64000000000000001, 'seasonality_period': 12}      0.024053
# WES {'alpha': 0.53000000000000003, 'gamma': 0.53000000000000003, 'seasonality_period': 12}      0.024128
# WES {'alpha': 0.65000000000000002, 'gamma': 0.65000000000000002, 'seasonality_period': 12}      0.024176
# WES {'alpha': 0.52000000000000002, 'gamma': 0.52000000000000002, 'seasonality_period': 12}      0.024289
# WES {'alpha': 0.66000000000000003, 'gamma': 0.66000000000000003, 'seasonality_period': 12}      0.024309
# WES {'alpha': 0.67000000000000004, 'gamma': 0.67000000000000004, 'seasonality_period': 12}      0.024449
# WES {'alpha': 0.51000000000000001, 'gamma': 0.51000000000000001, 'seasonality_period': 12}      0.024464
# WES {'alpha': 0.68000000000000005, 'gamma': 0.68000000000000005, 'seasonality_period': 12}      0.024607
# WES {'alpha': 0.5, 'gamma': 0.5, 'seasonality_period': 12}                                      0.024647
# WES {'alpha': 0.69000000000000006, 'gamma': 0.69000000000000006, 'seasonality_period': 12}      0.024796
# WES {'alpha': 0.48999999999999999, 'gamma': 0.48999999999999999, 'seasonality_period': 12}      0.024870
# WES {'alpha': 0.70000000000000007, 'gamma': 0.70000000000000007, 'seasonality_period': 12}      0.024996
# WES {'alpha': 0.48000000000000004, 'gamma': 0.48000000000000004, 'seasonality_period': 12}      0.025119
# WES {'alpha': 0.71000000000000008, 'gamma': 0.71000000000000008, 'seasonality_period': 12}      0.025207
# WES {'alpha': 0.47000000000000003, 'gamma': 0.47000000000000003, 'seasonality_period': 12}      0.025406
# WES {'alpha': 0.71999999999999997, 'gamma': 0.71999999999999997, 'seasonality_period': 12}      0.025430
# WES {'alpha': 0.72999999999999998, 'gamma': 0.72999999999999998, 'seasonality_period': 12}      0.025673
# WES {'alpha': 0.46000000000000002, 'gamma': 0.46000000000000002, 'seasonality_period': 12}      0.025754
# WES {'alpha': 0.73999999999999999, 'gamma': 0.73999999999999999, 'seasonality_period': 12}      0.025963
# WES {'alpha': 0.45000000000000001, 'gamma': 0.45000000000000001, 'seasonality_period': 12}      0.026120
#                                                                                                   ...
# WES {'alpha': 0.23000000000000001, 'gamma': 0.23000000000000001, 'seasonality_period': 12}      0.044087
# WES {'alpha': 0.22, 'gamma': 0.22, 'seasonality_period': 12}                                    0.045679
# WES {'alpha': 0.94000000000000006, 'gamma': 0.94000000000000006, 'seasonality_period': 12}      0.046109
# WES {'alpha': 0.21000000000000002, 'gamma': 0.21000000000000002, 'seasonality_period': 12}      0.047387
# WES {'alpha': 0.20000000000000001, 'gamma': 0.20000000000000001, 'seasonality_period': 12}      0.049218
# WES {'alpha': 0.95000000000000007, 'gamma': 0.95000000000000007, 'seasonality_period': 12}      0.050446
# WES {'alpha': 0.19, 'gamma': 0.19, 'seasonality_period': 12}                                    0.051176
# WES {'alpha': 0.18000000000000002, 'gamma': 0.18000000000000002, 'seasonality_period': 12}      0.053315
# WES {'alpha': 0.17000000000000001, 'gamma': 0.17000000000000001, 'seasonality_period': 12}      0.055638
# WES {'alpha': 0.96000000000000008, 'gamma': 0.96000000000000008, 'seasonality_period': 12}      0.056031
# WES {'alpha': 0.16, 'gamma': 0.16, 'seasonality_period': 12}                                    0.058230
# WES {'alpha': 0.15000000000000002, 'gamma': 0.15000000000000002, 'seasonality_period': 12}      0.061091
# WES {'alpha': 0.96999999999999997, 'gamma': 0.96999999999999997, 'seasonality_period': 12}      0.063377
# WES {'alpha': 0.14000000000000001, 'gamma': 0.14000000000000001, 'seasonality_period': 12}      0.064301
# WES {'alpha': 0.13, 'gamma': 0.13, 'seasonality_period': 12}                                    0.067862
# WES {'alpha': 0.12, 'gamma': 0.12, 'seasonality_period': 12}                                    0.071815
# WES {'alpha': 0.97999999999999998, 'gamma': 0.97999999999999998, 'seasonality_period': 12}      0.073135
# WES {'alpha': 0.11, 'gamma': 0.11, 'seasonality_period': 12}                                    0.076339
# WES {'alpha': 0.099999999999999992, 'gamma': 0.099999999999999992, 'seasonality_period': 12}    0.081537
# WES {'alpha': 0.98999999999999999, 'gamma': 0.98999999999999999, 'seasonality_period': 12}      0.086217
# WES {'alpha': 0.089999999999999997, 'gamma': 0.089999999999999997, 'seasonality_period': 12}    0.087628
# WES {'alpha': 0.080000000000000002, 'gamma': 0.080000000000000002, 'seasonality_period': 12}    0.095269
# WES {'alpha': 1.0, 'gamma': 1.0, 'seasonality_period': 12}                                      0.104680
# WES {'alpha': 0.069999999999999993, 'gamma': 0.069999999999999993, 'seasonality_period': 12}    0.104705
# WES {'alpha': 0.060000000000000005, 'gamma': 0.060000000000000005, 'seasonality_period': 12}    0.117324
# WES {'alpha': 0.050000000000000003, 'gamma': 0.050000000000000003, 'seasonality_period': 12}    0.133940
# WES {'alpha': 0.040000000000000001, 'gamma': 0.040000000000000001, 'seasonality_period': 12}    0.157058
# WES {'alpha': 0.029999999999999999, 'gamma': 0.029999999999999999, 'seasonality_period': 12}    0.191641
# WES {'alpha': 0.02, 'gamma': 0.02, 'seasonality_period': 12}                                    0.245730
# WES {'alpha': 0.01, 'gamma': 0.01, 'seasonality_period': 12}                                    0.337804
# dtype: float64

# %% [markdown]
# ## 3)

# %%
algName = QualityStr[QualityStr.columns].mean().sort_values().index[0]
plotTSForecast(wage.loc['1998-09-01':'2017-01-01'], FRC_WAGE_W[algName].loc['1998-09-01':'2017-01-01'],
               alg_title='WES')

# %% [markdown]
# ## 4)

# %%
qualityMACAPE(wage.loc['2015-02-01':'2017-01-01'], FRC_WAGE_W[algName].loc['2015-02-01':'2017-01-01'])[0]
# Out:
# Real wage    0.017125
# dtype: float64

# %% [markdown]
# ## Model has become much better due to accounting for seasonality! _But_ it still doesn't take trend into consideration.

# %% [markdown]
# # 4. Theil-Wage model for TS with linear trend and seasonality (25%)
# You need to realize Theil-Wage model and then use it for forecasting real TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
# * 1) Realize Theil-Wage model for
# * 2) Find optimal params $\alpha$ (smoothing of level), $\beta$ (smoothing trend) and $\gamma$ (smoothing of seasonality) (use data from 09.1998 to 01.2015).(Loss function should be the same as in task 2.)
# * 3) Draw forecast with optimal values $\alpha$, $\beta$ and $\gamma$ from 09.1998 to 01.2017.
# * 4) Calculate accuracy of the forecast of TS in [02.2015, 01.2017] (Loss function should be the same as in task 2.). Compare it with accuracy of Winters model: is it better than the last one?
# * \*5) Suggest how can the Theil-Wage model be improved to make accuracy of forecast better?

# %% [markdown]
# ## 1) -> utils.py

# %% [markdown]
# ## 2)

# %%
# Put your code here
ALPHA = np.linspace(0.01,1,100) # season ~ year
TWESParamsArray = [{'alpha':alpha, 'gamma':gamma, 'beta':beta, 'seasonality_period':12}
                  for (alpha, gamma, beta) in zip(ALPHA, ALPHA, ALPHA)]
FRC_WAGE_TW = BuildForecast(h=1, ts=wage, step='M', AlgName='TheilWageExponentialSmoothing', AlgTitle='TWES',ParamsArray = TWESParamsArray)

# %%
# compare ES parameters
QualityStr = pd.DataFrame(index=wage.columns, columns=FRC_WAGE_TW.keys())

ix = wage.loc['1998-09-01':'2015-01-01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = FRC_WAGE_TW[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[ix], frc_wage.loc[ix])

QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# TWES {'alpha': 0.34000000000000002, 'gamma': 0.34000000000000002, 'beta': 0.34000000000000002, 'seasonality_period': 12}       0.032371
# TWES {'alpha': 0.35000000000000003, 'gamma': 0.35000000000000003, 'beta': 0.35000000000000003, 'seasonality_period': 12}       0.032374
# TWES {'alpha': 0.36000000000000004, 'gamma': 0.36000000000000004, 'beta': 0.36000000000000004, 'seasonality_period': 12}       0.032519
# TWES {'alpha': 0.33000000000000002, 'gamma': 0.33000000000000002, 'beta': 0.33000000000000002, 'seasonality_period': 12}       0.032617
# TWES {'alpha': 0.37, 'gamma': 0.37, 'beta': 0.37, 'seasonality_period': 12}                                                    0.032842
# TWES {'alpha': 0.32000000000000001, 'gamma': 0.32000000000000001, 'beta': 0.32000000000000001, 'seasonality_period': 12}       0.033035
# TWES {'alpha': 0.38, 'gamma': 0.38, 'beta': 0.38, 'seasonality_period': 12}                                                    0.033357
# TWES {'alpha': 0.31, 'gamma': 0.31, 'beta': 0.31, 'seasonality_period': 12}                                                    0.033542
# TWES {'alpha': 0.29999999999999999, 'gamma': 0.29999999999999999, 'beta': 0.29999999999999999, 'seasonality_period': 12}       0.034070
# TWES {'alpha': 0.39000000000000001, 'gamma': 0.39000000000000001, 'beta': 0.39000000000000001, 'seasonality_period': 12}       0.034125
# TWES {'alpha': 0.29000000000000004, 'gamma': 0.29000000000000004, 'beta': 0.29000000000000004, 'seasonality_period': 12}       0.034611
# TWES {'alpha': 0.28000000000000003, 'gamma': 0.28000000000000003, 'beta': 0.28000000000000003, 'seasonality_period': 12}       0.035151
# TWES {'alpha': 0.40000000000000002, 'gamma': 0.40000000000000002, 'beta': 0.40000000000000002, 'seasonality_period': 12}       0.035153
# TWES {'alpha': 0.27000000000000002, 'gamma': 0.27000000000000002, 'beta': 0.27000000000000002, 'seasonality_period': 12}       0.035754
# TWES {'alpha': 0.41000000000000003, 'gamma': 0.41000000000000003, 'beta': 0.41000000000000003, 'seasonality_period': 12}       0.036411
# TWES {'alpha': 0.26000000000000001, 'gamma': 0.26000000000000001, 'beta': 0.26000000000000001, 'seasonality_period': 12}       0.036629
# TWES {'alpha': 0.25, 'gamma': 0.25, 'beta': 0.25, 'seasonality_period': 12}                                                    0.037453
# TWES {'alpha': 0.42000000000000004, 'gamma': 0.42000000000000004, 'beta': 0.42000000000000004, 'seasonality_period': 12}       0.037902
# TWES {'alpha': 0.24000000000000002, 'gamma': 0.24000000000000002, 'beta': 0.24000000000000002, 'seasonality_period': 12}       0.038183
# TWES {'alpha': 0.23000000000000001, 'gamma': 0.23000000000000001, 'beta': 0.23000000000000001, 'seasonality_period': 12}       0.039129
# TWES {'alpha': 0.42999999999999999, 'gamma': 0.42999999999999999, 'beta': 0.42999999999999999, 'seasonality_period': 12}       0.039487
# TWES {'alpha': 0.22, 'gamma': 0.22, 'beta': 0.22, 'seasonality_period': 12}                                                    0.040110
# TWES {'alpha': 0.21000000000000002, 'gamma': 0.21000000000000002, 'beta': 0.21000000000000002, 'seasonality_period': 12}       0.041127
# TWES {'alpha': 0.44, 'gamma': 0.44, 'beta': 0.44, 'seasonality_period': 12}                                                    0.041405
# TWES {'alpha': 0.20000000000000001, 'gamma': 0.20000000000000001, 'beta': 0.20000000000000001, 'seasonality_period': 12}       0.042092
# TWES {'alpha': 0.19, 'gamma': 0.19, 'beta': 0.19, 'seasonality_period': 12}                                                    0.043262
# TWES {'alpha': 0.45000000000000001, 'gamma': 0.45000000000000001, 'beta': 0.45000000000000001, 'seasonality_period': 12}       0.043437
# TWES {'alpha': 0.71999999999999997, 'gamma': 0.71999999999999997, 'beta': 0.71999999999999997, 'seasonality_period': 12}       0.044539
# TWES {'alpha': 0.72999999999999998, 'gamma': 0.72999999999999998, 'beta': 0.72999999999999998, 'seasonality_period': 12}       0.044623
# TWES {'alpha': 0.71000000000000008, 'gamma': 0.71000000000000008, 'beta': 0.71000000000000008, 'seasonality_period': 12}       0.044629
#                                                                                                                                  ...
# TWES {'alpha': 0.53000000000000003, 'gamma': 0.53000000000000003, 'beta': 0.53000000000000003, 'seasonality_period': 12}       0.057598
# TWES {'alpha': 0.58000000000000007, 'gamma': 0.58000000000000007, 'beta': 0.58000000000000007, 'seasonality_period': 12}       0.058167
# TWES {'alpha': 0.54000000000000004, 'gamma': 0.54000000000000004, 'beta': 0.54000000000000004, 'seasonality_period': 12}       0.058451
# TWES {'alpha': 0.57000000000000006, 'gamma': 0.57000000000000006, 'beta': 0.57000000000000006, 'seasonality_period': 12}       0.058943
# TWES {'alpha': 0.55000000000000004, 'gamma': 0.55000000000000004, 'beta': 0.55000000000000004, 'seasonality_period': 12}       0.059030
# TWES {'alpha': 0.56000000000000005, 'gamma': 0.56000000000000005, 'beta': 0.56000000000000005, 'seasonality_period': 12}       0.059054
# TWES {'alpha': 0.89000000000000001, 'gamma': 0.89000000000000001, 'beta': 0.89000000000000001, 'seasonality_period': 12}       0.059271
# TWES {'alpha': 0.12, 'gamma': 0.12, 'beta': 0.12, 'seasonality_period': 12}                                                    0.060737
# TWES {'alpha': 0.90000000000000002, 'gamma': 0.90000000000000002, 'beta': 0.90000000000000002, 'seasonality_period': 12}       0.061136
# TWES {'alpha': 0.91000000000000003, 'gamma': 0.91000000000000003, 'beta': 0.91000000000000003, 'seasonality_period': 12}       0.062952
# TWES {'alpha': 0.92000000000000004, 'gamma': 0.92000000000000004, 'beta': 0.92000000000000004, 'seasonality_period': 12}       0.064802
# TWES {'alpha': 0.11, 'gamma': 0.11, 'beta': 0.11, 'seasonality_period': 12}                                                    0.064811
# TWES {'alpha': 0.93000000000000005, 'gamma': 0.93000000000000005, 'beta': 0.93000000000000005, 'seasonality_period': 12}       0.066833
# TWES {'alpha': 0.099999999999999992, 'gamma': 0.099999999999999992, 'beta': 0.099999999999999992, 'seasonality_period': 12}    0.068716
# TWES {'alpha': 0.94000000000000006, 'gamma': 0.94000000000000006, 'beta': 0.94000000000000006, 'seasonality_period': 12}       0.068893
# TWES {'alpha': 0.95000000000000007, 'gamma': 0.95000000000000007, 'beta': 0.95000000000000007, 'seasonality_period': 12}       0.071493
# TWES {'alpha': 0.089999999999999997, 'gamma': 0.089999999999999997, 'beta': 0.089999999999999997, 'seasonality_period': 12}    0.072758
# TWES {'alpha': 0.96000000000000008, 'gamma': 0.96000000000000008, 'beta': 0.96000000000000008, 'seasonality_period': 12}       0.075136
# TWES {'alpha': 0.080000000000000002, 'gamma': 0.080000000000000002, 'beta': 0.080000000000000002, 'seasonality_period': 12}    0.076444
# TWES {'alpha': 0.069999999999999993, 'gamma': 0.069999999999999993, 'beta': 0.069999999999999993, 'seasonality_period': 12}    0.078848
# TWES {'alpha': 0.96999999999999997, 'gamma': 0.96999999999999997, 'beta': 0.96999999999999997, 'seasonality_period': 12}       0.081269
# TWES {'alpha': 0.060000000000000005, 'gamma': 0.060000000000000005, 'beta': 0.060000000000000005, 'seasonality_period': 12}    0.082395
# TWES {'alpha': 0.050000000000000003, 'gamma': 0.050000000000000003, 'beta': 0.050000000000000003, 'seasonality_period': 12}    0.089998
# TWES {'alpha': 0.97999999999999998, 'gamma': 0.97999999999999998, 'beta': 0.97999999999999998, 'seasonality_period': 12}       0.091039
# TWES {'alpha': 0.98999999999999999, 'gamma': 0.98999999999999999, 'beta': 0.98999999999999999, 'seasonality_period': 12}       0.102092
# TWES {'alpha': 0.040000000000000001, 'gamma': 0.040000000000000001, 'beta': 0.040000000000000001, 'seasonality_period': 12}    0.108741
# TWES {'alpha': 1.0, 'gamma': 1.0, 'beta': 1.0, 'seasonality_period': 12}                                                       0.114571
# TWES {'alpha': 0.029999999999999999, 'gamma': 0.029999999999999999, 'beta': 0.029999999999999999, 'seasonality_period': 12}    0.150804
# TWES {'alpha': 0.02, 'gamma': 0.02, 'beta': 0.02, 'seasonality_period': 12}                                                    0.249906
# TWES {'alpha': 0.01, 'gamma': 0.01, 'beta': 0.01, 'seasonality_period': 12}                                                    0.674590
# dtype: float64

# %% [markdown]
# ## 3)

# %%
algName = QualityStr[QualityStr.columns].mean().sort_values().index[0]
plotTSForecast(wage.loc['1998-09-01':'2017-01-01'], FRC_WAGE_TW[algName].loc['1998-09-01':'2017-01-01'],
               alg_title='TWES')

# %%
qualityMACAPE(wage.loc['2015-02-01':'2017-01-01'], FRC_WAGE_TW[algName].loc['2015-02-01':'2017-01-01'])[0]
# Out:
# Real wage    0.025126
# dtype: float64

# %% [markdown]
# # 5. Non-additive model of ES (25%)
# You need to realize some ES-model that include non-addive component (or multiplicative trend or multiplicative component) and then use it for forecasting real TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
# * 1) Realize one of following ES models: ESM(A,M) (t.e. Holt-Winters model), ESM(Ad,M), ESM(M,A), ESM(M,M) model.
# * 2) Find optimal params of the model (use data from 09.1998 to 01.2015). Note: if you choose damped trend model that $\phi$ you can just set it by expert opinion (say $0.98$). (Loss function should be the same as in task 2.)
# * 3) Draw forecast with optimal values of it's params (data from 09.1998 to 01.2017).
# * 4) Calculate accuracy of the forecast of TS in [02.2015, 01.2017] (Loss function should be the same as in task 2.). Compare it with accuracy of Winters model and Theil-Wage model: is it better than the last one?
# * 5) Is it true that multiplicative model are more unstable than additive? Unstable means thet forecast is can diveret

# %%
# Put your code here
ALPHA = np.linspace(0.01,1,100) # season ~ year
MWESParamsArray = [{'alpha':alpha, 'gamma':gamma, 'seasonality_period':12}
                  for (alpha, gamma) in zip(ALPHA, ALPHA)]
FRC_WAGE_MW = BuildForecast(h=1, ts=wage, step='M', AlgName='MultiWintersExponentialSmoothing',
                            AlgTitle='MWES',ParamsArray = MWESParamsArray)

# %%
# compare ES parameters
QualityStr = pd.DataFrame(index=wage.columns, columns=FRC_WAGE_MW.keys())

ix = wage.loc['1998-09-01':'2015-01-01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = FRC_WAGE_MW[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[ix], frc_wage.loc[ix])

QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# MWES {'alpha': 0.63, 'gamma': 0.63, 'seasonality_period': 12}                                    0.022549
# MWES {'alpha': 0.62, 'gamma': 0.62, 'seasonality_period': 12}                                    0.022561
# MWES {'alpha': 0.64000000000000001, 'gamma': 0.64000000000000001, 'seasonality_period': 12}      0.022566
# MWES {'alpha': 0.65000000000000002, 'gamma': 0.65000000000000002, 'seasonality_period': 12}      0.022588
# MWES {'alpha': 0.60999999999999999, 'gamma': 0.60999999999999999, 'seasonality_period': 12}      0.022591
# MWES {'alpha': 0.66000000000000003, 'gamma': 0.66000000000000003, 'seasonality_period': 12}      0.022618
# MWES {'alpha': 0.59999999999999998, 'gamma': 0.59999999999999998, 'seasonality_period': 12}      0.022628
# MWES {'alpha': 0.67000000000000004, 'gamma': 0.67000000000000004, 'seasonality_period': 12}      0.022654
# MWES {'alpha': 0.58999999999999997, 'gamma': 0.58999999999999997, 'seasonality_period': 12}      0.022673
# MWES {'alpha': 0.68000000000000005, 'gamma': 0.68000000000000005, 'seasonality_period': 12}      0.022706
# MWES {'alpha': 0.58000000000000007, 'gamma': 0.58000000000000007, 'seasonality_period': 12}      0.022743
# MWES {'alpha': 0.69000000000000006, 'gamma': 0.69000000000000006, 'seasonality_period': 12}      0.022774
# MWES {'alpha': 0.70000000000000007, 'gamma': 0.70000000000000007, 'seasonality_period': 12}      0.022866
# MWES {'alpha': 0.57000000000000006, 'gamma': 0.57000000000000006, 'seasonality_period': 12}      0.022879
# MWES {'alpha': 0.71000000000000008, 'gamma': 0.71000000000000008, 'seasonality_period': 12}      0.022981
# MWES {'alpha': 0.56000000000000005, 'gamma': 0.56000000000000005, 'seasonality_period': 12}      0.023030
# MWES {'alpha': 0.71999999999999997, 'gamma': 0.71999999999999997, 'seasonality_period': 12}      0.023117
# MWES {'alpha': 0.55000000000000004, 'gamma': 0.55000000000000004, 'seasonality_period': 12}      0.023199
# MWES {'alpha': 0.72999999999999998, 'gamma': 0.72999999999999998, 'seasonality_period': 12}      0.023280
# MWES {'alpha': 0.54000000000000004, 'gamma': 0.54000000000000004, 'seasonality_period': 12}      0.023385
# MWES {'alpha': 0.73999999999999999, 'gamma': 0.73999999999999999, 'seasonality_period': 12}      0.023471
# MWES {'alpha': 0.53000000000000003, 'gamma': 0.53000000000000003, 'seasonality_period': 12}      0.023585
# MWES {'alpha': 0.75, 'gamma': 0.75, 'seasonality_period': 12}                                    0.023674
# MWES {'alpha': 0.52000000000000002, 'gamma': 0.52000000000000002, 'seasonality_period': 12}      0.023791
# MWES {'alpha': 0.76000000000000001, 'gamma': 0.76000000000000001, 'seasonality_period': 12}      0.023887
# MWES {'alpha': 0.51000000000000001, 'gamma': 0.51000000000000001, 'seasonality_period': 12}      0.024006
# MWES {'alpha': 0.77000000000000002, 'gamma': 0.77000000000000002, 'seasonality_period': 12}      0.024121
# MWES {'alpha': 0.5, 'gamma': 0.5, 'seasonality_period': 12}                                      0.024231
# MWES {'alpha': 0.78000000000000003, 'gamma': 0.78000000000000003, 'seasonality_period': 12}      0.024376
# MWES {'alpha': 0.48999999999999999, 'gamma': 0.48999999999999999, 'seasonality_period': 12}      0.024487
#                                                                                                    ...
# MWES {'alpha': 0.23000000000000001, 'gamma': 0.23000000000000001, 'seasonality_period': 12}      0.043449
# MWES {'alpha': 0.22, 'gamma': 0.22, 'seasonality_period': 12}                                    0.044989
# MWES {'alpha': 0.94000000000000006, 'gamma': 0.94000000000000006, 'seasonality_period': 12}      0.045836
# MWES {'alpha': 0.21000000000000002, 'gamma': 0.21000000000000002, 'seasonality_period': 12}      0.046629
# MWES {'alpha': 0.20000000000000001, 'gamma': 0.20000000000000001, 'seasonality_period': 12}      0.048378
# MWES {'alpha': 0.19, 'gamma': 0.19, 'seasonality_period': 12}                                    0.050281
# MWES {'alpha': 0.95000000000000007, 'gamma': 0.95000000000000007, 'seasonality_period': 12}      0.050813
# MWES {'alpha': 0.18000000000000002, 'gamma': 0.18000000000000002, 'seasonality_period': 12}      0.052361
# MWES {'alpha': 0.17000000000000001, 'gamma': 0.17000000000000001, 'seasonality_period': 12}      0.054661
# MWES {'alpha': 0.96000000000000008, 'gamma': 0.96000000000000008, 'seasonality_period': 12}      0.057033
# MWES {'alpha': 0.16, 'gamma': 0.16, 'seasonality_period': 12}                                    0.057211
# MWES {'alpha': 0.15000000000000002, 'gamma': 0.15000000000000002, 'seasonality_period': 12}      0.060006
# MWES {'alpha': 0.14000000000000001, 'gamma': 0.14000000000000001, 'seasonality_period': 12}      0.063173
# MWES {'alpha': 0.96999999999999997, 'gamma': 0.96999999999999997, 'seasonality_period': 12}      0.064852
# MWES {'alpha': 0.13, 'gamma': 0.13, 'seasonality_period': 12}                                    0.066691
# MWES {'alpha': 0.12, 'gamma': 0.12, 'seasonality_period': 12}                                    0.070623
# MWES {'alpha': 0.97999999999999998, 'gamma': 0.97999999999999998, 'seasonality_period': 12}      0.075012
# MWES {'alpha': 0.11, 'gamma': 0.11, 'seasonality_period': 12}                                    0.075188
# MWES {'alpha': 0.099999999999999992, 'gamma': 0.099999999999999992, 'seasonality_period': 12}    0.080508
# MWES {'alpha': 0.089999999999999997, 'gamma': 0.089999999999999997, 'seasonality_period': 12}    0.087020
# MWES {'alpha': 0.98999999999999999, 'gamma': 0.98999999999999999, 'seasonality_period': 12}      0.088628
# MWES {'alpha': 0.080000000000000002, 'gamma': 0.080000000000000002, 'seasonality_period': 12}    0.094740
# MWES {'alpha': 0.069999999999999993, 'gamma': 0.069999999999999993, 'seasonality_period': 12}    0.104263
# MWES {'alpha': 1.0, 'gamma': 1.0, 'seasonality_period': 12}                                      0.107485
# MWES {'alpha': 0.060000000000000005, 'gamma': 0.060000000000000005, 'seasonality_period': 12}    0.116731
# MWES {'alpha': 0.050000000000000003, 'gamma': 0.050000000000000003, 'seasonality_period': 12}    0.133741
# MWES {'alpha': 0.040000000000000001, 'gamma': 0.040000000000000001, 'seasonality_period': 12}    0.157381
# MWES {'alpha': 0.029999999999999999, 'gamma': 0.029999999999999999, 'seasonality_period': 12}    0.192350
# MWES {'alpha': 0.02, 'gamma': 0.02, 'seasonality_period': 12}                                    0.246493
# MWES {'alpha': 0.01, 'gamma': 0.01, 'seasonality_period': 12}                                    0.339014
# dtype: float64

# %%
algName = QualityStr[QualityStr.columns].mean().sort_values().index[0]
plotTSForecast(wage.loc['1998-09-01':'2017-01-01'], FRC_WAGE_MW[algName].loc['1998-09-01':'2017-01-01'],
               alg_title='MWES')

# %%
qualityMACAPE(wage.loc['2015-02-01':'2017-01-01'], FRC_WAGE_MW[algName].loc['2015-02-01':'2017-01-01'])[0]
# Out:
# Real wage    0.014108
# dtype: float64

# %% [markdown]
# ## Since seasonality has multiplicative structure, corresponding Winters model performs better than first one
